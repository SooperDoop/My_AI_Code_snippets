# %%
import requests

# %%
r = requests.get('http://php.net')

# %%
import nltk

# %%
import bs4

# %%
import urllib.request,urllib.response

# %%
res = urllib.request.urlopen('https://www.google.com/')
htm = res.read()

# %%
htm,r.text
# Out:
# (b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="b1O0QIx+otHkN30hIxyAqw==">(function(){window.google={kEI:\'-ORuXLnrEIjl_QbSzLf4Ag\',kEXPI:\'0,1353747,57,1957,1017,1406,698,527,591,139,1799,30,1228,805,956,121,107,230,202,18,2,37,2334635,329506,1294,12383,4855,32691,15248,867,10761,1402,5281,1100,854,2481,2,2,4604,2197,364,1172,2147,5505,224,1017,1195,266,5107,575,835,284,2,297,282,727,2432,58,2,1,3,1297,4323,3390,8,302,1267,774,2254,1403,1414,1923,7,1139,5,2,2,1963,2595,182,3419,669,1048,3,1807,1129,268,81,7,1,2,488,620,
# ...

# %%
sup = bs4.BeautifulSoup(r.text,'html5lib')
sup1 = bs4.BeautifulSoup(htm,'html5lib')

# %%
txt = sup.get_text(strip=True)
txt2 = sup1.get_text(strip=True)

# %%
tok = [t for t in txt.split()]

# %%
c = nltk.FreqDist(txt.split())
cc = nltk.FreqDist(txt2.split())

# %%
c.plot(20),cc.plot(20)

# %%
lip = requests.get('https://www.lipsum.com/')

# %%
lip_sup = bs4.BeautifulSoup(lip.text,'html5lib')

# %%
lip_fre = nltk.FreqDist(lip_sup.get_text(strip=True).split())

# %%
lip_fre.plot(20,cumulative = False)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')

# %%
txt3 = lip_sup.get_text(strip=True).split()

# %%
txt4 = set(txt3) - set(stopwords.words('english'))

# %%
fre = nltk.FreqDist(txt4)

# %%
fre.plot(20)

# %%
text = '''Hello Adam, how are you? I hope everything is going well. Today is a good day, see you dude.
Hello Mr. Adam, how are you? I hope everything is going well. Today is a good day, see you dude.'''

# %%
s = set(text.split())-set(stopwords.words('english'))

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import networkx as nx
import matplotlib
from nltk.corpus import wordnet as wn

# %%
synonyms,G
# Out:
# (['computer',
#   'computing_machine',
#   'computing_device',
#   'data_processor',
#   'electronic_computer',
#   'information_processing_system',
#   'calculator',
#   'reckoner',
#   'figurer',
#   'estimator',
#   'computer'],
#  <networkx.classes.graph.Graph at 0x7f483da67cf8>)

# %%
text = bs4.BeautifulSoup(lip.text,'html5lib')

# %%
text = text.get_text(strip=True).split()

# %%
nltk.FreqDist(text).plot(20)

# %%
from wordcloud import WordCloud

# %%
plt.figure(figsize = (15, 7), facecolor = 'None',)
plt.imshow(WordCloud().generate(str(text)))
plt.axis('off')
plt.show()

# %%
nltk.FreqDist(set(text.split())-set(stopwords.words('english'))).plot(20)
